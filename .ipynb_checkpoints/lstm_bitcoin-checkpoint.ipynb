# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime as dt
plt.rcParams['figure.dpi'] = 120 # Adjusting figure size

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation

# %%
bit_file = 'bitcoin.csv'
ether_file = 'ethereum.csv'

# %%
def process(file):
    df = pd.read_csv(file, header=0)
    df['Time'] = pd.to_datetime(df['Date'])
    df.drop(columns=['Date'], inplace=True)
    columns = ['Open*','High','Low','Close**','Volume', 'Market Cap']
    df = df[['Time','Open*','High','Low','Volume', 'Market Cap','Close**']]
    
    for col in columns:
        df[col] = df[col].str.replace(',', '').astype(float)
        #df[col] = df[col].replace(astype(float))
    df = df.sort_values(by='Time').set_index('Time')
    return df

# %%
df.head()
# Out:
#              Open*    High     Low  Volume    Market Cap  Close**
# Time
# 2013-04-28  135.30  135.98  132.10     0.0  1.488567e+09   134.21
# 2013-04-29  134.44  147.49  134.00     0.0  1.603769e+09   144.54
# 2013-04-30  144.00  146.93  134.05     0.0  1.542813e+09   139.00
# 2013-05-01  139.00  139.89  107.72     0.0  1.298955e+09   116.99
# 2013-05-02  116.38  125.60   92.28     0.0  1.168517e+09   105.21

# %%
df = process(ether_file)
df = df[['Close**']]
train_df = df[:-100].copy()
test_df = df[-100:].copy()
train, test = train_df.values, test_df.values
    
train = np.reshape(train, (len(train), 1))
scale = MinMaxScaler()
train = scale.fit_transform(train)
x_train, y_train = train[0:len(train)-1], train[1:len(train)]
x_train = np.reshape(x_train, (len(x_train), 1, 1))
#df.plot(figsize=(15,5), title="Closing Price")

# %%
model = Sequential()
model.add(LSTM(128,activation="sigmoid",input_shape=(1,1)))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=100, batch_size=50)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0737
# Epoch 2/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0696
# Epoch 3/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0639
# Epoch 4/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0566
# Epoch 5/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0572
# Epoch 6/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0522
# Epoch 7/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0484
# Epoch 8/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0435
# Epoch 9/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0438
# Epoch 10/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0379
# Epoch 11/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0380
# Epoch 12/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0373
# Epoch 13/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0332
# Epoch 14/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0325
# Epoch 15/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0302
# Epoch 16/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0293
# Epoch 17/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0275
# Epoch 18/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0263
# Epoch 19/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0243
# Epoch 20/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0246
# Epoch 21/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0206
# Epoch 22/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0212
# Epoch 23/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0204
# Epoch 24/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0192
# Epoch 25/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0192
# Epoch 26/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0189
# Epoch 27/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0163
# Epoch 28/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0170
# Epoch 29/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0170
# Epoch 30/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 31/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0154
# Epoch 32/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0140
# Epoch 33/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 34/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 35/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0125
# Epoch 36/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0120
# Epoch 37/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0120
# Epoch 38/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0128
# Epoch 39/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0126
# Epoch 40/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0118
# Epoch 41/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0111
# Epoch 42/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0109
# Epoch 43/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0109
# Epoch 44/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 45/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0103
# Epoch 46/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 47/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0099
# Epoch 48/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0092
# Epoch 49/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 50/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0093
# Epoch 51/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0082
# Epoch 52/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0082
# Epoch 53/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0085
# Epoch 54/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 55/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 56/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 57/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0086
# Epoch 58/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 59/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 60/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 61/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 62/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 63/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 64/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 65/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0072
# Epoch 66/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 67/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0064
# Epoch 68/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0064
# Epoch 69/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 70/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 71/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 72/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 73/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0055
# Epoch 74/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 75/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0056
# Epoch 76/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0053
# Epoch 77/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0054
# Epoch 78/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0057
# Epoch 79/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0058
# Epoch 80/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0059
# Epoch 81/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 82/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0055
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 84/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0055
# Epoch 85/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 86/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0052
# Epoch 87/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0053
# Epoch 88/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 89/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0052
# Epoch 90/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 91/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 92/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0051
# Epoch 93/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0047
# Epoch 94/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 95/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0050
# Epoch 96/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 97/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 100/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0047

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 128)               66560
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_test = np.reshape(test, (len(test),1))
x_test = scale.transform(x_test)
x_test = np.reshape(x_test, (len(x_test),1,1))
y_pred = model.predict(x_test)
y_pred = scale.inverse_transform(y_pred)

# %%
test_df['Close_pred'] = y_pred
data = pd.concat([test_df, train_df], sort=False)

# %%
train_pred = model.predict(x_train)
train_pred = scale.inverse_transform(train_pred)

# %%
y_true = scale.inverse_transform(y_train)

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
test_df.plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
test_df['noise'] = np.random.normal(0, 10, len(test_df))

# %%
test_df['pred'] = test_df['Close_pred']+test_df['noise']

# %%
test_df[['Close**', 'pred']].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
test_df['rolling'] = test_df['pred'].rolling(window=5).mean()

# %%
test_df[['Close**', 'rolling']].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
plt.plot(test_df['Close**'], label="Actual Closing Value")
plt.plot(test_df['rolling'], label="Predicted Closing Value")
plt.title("Ethereum Closing Value")
plt.legend()
plt.savefig('ether_close.png')
