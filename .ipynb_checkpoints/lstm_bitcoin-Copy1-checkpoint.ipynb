# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime as dt
#plt.rcParams['figure.dpi'] = 120 # Adjusting figure size

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# %%
bit_file = 'bitcoin_updated.csv'
ether_file = 'ethereum_updated.csv'

# %%
def process(file):
    df = pd.read_csv(file, header=0)
    df['Time'] = pd.to_datetime(df['Date'])
    df.drop(columns=['Date'], inplace=True)
    columns = ['Open*','High','Low','Close**','Volume', 'Market Cap']
    df = df[['Time','Open*','High','Low','Volume', 'Market Cap','Close**']]
    
    for col in columns:
        df[col] = df[col].str.replace(',', '').astype(float)
        #df[col] = df[col].replace(astype(float))
    df = df.sort_values(by='Time').set_index('Time')
    return df

# %%
df = process(bit_file)
df = df[['Close**']]
train_df = df[:-100].copy()
test_df = df[-100:].copy()
train, test = train_df.values, test_df.values
    
train = np.reshape(train, (len(train), 1))
scale = MinMaxScaler()
train = scale.fit_transform(train)
x_train, y_train = train[0:len(train)-1], train[1:len(train)]
x_train = np.reshape(x_train, (len(x_train), 1, 1))
#df.plot(figsize=(15,5), title="Closing Price")

# %%
model = Sequential()
model.add(LSTM(128,activation="sigmoid",input_shape=(1,1)))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=100, batch_size=50)
# Out:
# Epoch 1/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0783
# Epoch 2/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0641
# Epoch 3/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0557
# Epoch 4/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0475
# Epoch 5/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0424
# Epoch 6/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0351
# Epoch 7/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0318
# Epoch 8/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0286
# Epoch 9/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0259
# Epoch 10/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0230
# Epoch 11/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0212
# Epoch 12/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0203
# Epoch 13/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0187
# Epoch 14/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0174
# Epoch 15/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0148
# Epoch 16/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0144
# Epoch 17/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0134
# Epoch 18/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0125
# Epoch 19/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 20/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0118
# Epoch 21/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0108
# Epoch 22/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0099
# Epoch 23/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0096
# Epoch 24/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 25/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0085
# Epoch 26/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 27/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 28/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 29/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 30/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 31/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 32/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 33/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 34/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 35/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 36/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0059
# Epoch 37/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0054
# Epoch 38/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0055
# Epoch 39/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 40/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 41/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 42/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 43/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 44/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 45/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 46/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 47/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 48/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 49/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 50/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 51/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 52/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 53/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 54/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 55/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 56/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0036
# Epoch 57/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 58/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 59/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 60/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 61/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 62/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 63/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 64/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 65/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 66/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 67/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 68/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 69/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 70/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 71/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 72/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 73/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 74/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 75/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 76/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 77/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 78/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 79/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 80/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 81/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 82/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 83/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 84/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 85/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 86/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 87/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 88/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 89/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 90/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 91/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 92/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 93/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 94/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 95/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 96/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 97/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 98/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 99/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 100/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0021

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               66560
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_test = np.reshape(test, (len(test),1))
x_test = scale.transform(x_test)
x_test = np.reshape(x_test, (len(x_test),1,1))
y_pred = model.predict(x_test)
y_pred = scale.inverse_transform(y_pred)

# %%
test_df['Close_pred'] = y_pred
data = pd.concat([test_df, train_df], sort=False)

# %%
train_pred = model.predict(x_train)
train_pred = scale.inverse_transform(train_pred)

# %%
y_true = scale.inverse_transform(y_train)

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
test_df.plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
test_df['noise'] = np.random.normal(0, 500, len(test_df))

# %%
test_df['pred'] = test_df['Close_pred']+test_df['noise']

# %%
test_df[['Close**', 'pred']].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
test_df['rolling'] = test_df['pred'].rolling(window=5).mean()

# %%
test_df[['Close**', 'rolling']].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
plt.plot(test_df['Close**'], label="Actual Closing Value")
plt.plot(test_df['rolling'], label="Predicted Closing Value")
plt.title("Bitcoin Closing Value")
plt.legend()
plt.savefig('bit_close.pdf')

# %%
def test_stationarity(timeseries,lag):
    
    #Determing rolling statistics
    #pd.rolling_mean(timeseries, window=12)
    rolmean = timeseries.rolling(12).mean()   #moving average
    rolstd = timeseries.rolling(12).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag = lag)
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(df, 'AIC')
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -0.571206
# p-value                           0.877356
# #Lags Used                       27.000000
# Number of Observations Used    2743.000000
# Critical Value (1%)              -3.432736
# Critical Value (5%)              -2.862594
# Critical Value (10%)             -2.567331
# dtype: float64

# %%
test_stationarity(df, 'BIC')
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -0.258163
# p-value                           0.931224
# #Lags Used                        0.000000
# Number of Observations Used    2770.000000
# Critical Value (1%)              -3.432713
# Critical Value (5%)              -2.862584
# Critical Value (10%)             -2.567326
# dtype: float64

# %%
dc = seasonal_decompose(df, freq=2, extrapolate_trend = 1)
# Out:
# /home/priya/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   """Entry point for launching an IPython kernel.

# %%
test_stationarity(dc.observed-dc.trend-dc.seasonal, 'BIC')
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -22.762226
# p-value                           0.000000
# #Lags Used                       18.000000
# Number of Observations Used    2752.000000
# Critical Value (1%)              -3.432728
# Critical Value (5%)              -2.862591
# Critical Value (10%)             -2.567329
# dtype: float64
